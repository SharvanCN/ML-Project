# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_x = pd.read_csv('polynomial_train.csv')

# %%
x_train = df_x.to_numpy()
y_train = x_train[:,4]
x_train = np.delete(x_train, [0,4] , axis = 1)

# %%
x_train_mean = np.mean(x_train, axis = 0) 
x_train_std = np.std(x_train, axis = 0)
x_train = (x_train-x_train_mean)/x_train_std
n = 5
q = x_train[:, 0]
p = x_train[:, 1]
e = x_train[:, 2]

# %%
model_polynomial = []

for i in range(n+1):
    for j in range(n+1):
        for k in range(n+1):
            if i+j+k <= n & i+j+k>0:
            
                term = (q**i) * (p**j) * (e**k)
                model_polynomial.append(term)

model_polynomial = np.array(model_polynomial).T
print(model_polynomial.shape)
# Out:
# (50000, 39)

# %%
m,n = x_train.shape
w_initial = np.zeros(model_polynomial.shape[1])
b_initial = 0
y_hat = np.zeros(model_polynomial.shape[0])
dj_dw = np.zeros(model_polynomial.shape[1])
dj_db = 0
tmp_alpha = 10**-2.88
iterations = 1500
lamda = 0.01
J_history = []
p_history = []

# %%
x_traintrain = np.delete(model_polynomial, range(10000, 20000), axis  = 0)
nn = x_traintrain.shape[0]
x_traintest = model_polynomial[10000:20000 , :]
y_traintrain = np.delete(y_train, range(10000,20000), axis = 0)
y_traintest = y_train[10000:20000]
y_meanmean = np.sum(y_traintest)/10000

# %%
def model(x, w, b):
    y_hat = np.dot(x, w) + b
    return y_hat

# %%
def cost_func(y_hat, y, w, lamda):
    loss = np.square(y_hat - y)/2
    cost_1 = np.mean(loss)
    cost_2 = lamda*np.square(w)
    cost_3 = np.sum(cost_2/(2*model_polynomial.shape[1]))
    final_cost = cost_1 + cost_3
    return final_cost

# %%
def grad(x, y, y_hat):
    dj_dw = (np.dot(x.T, (y_hat - y)))/m
    dj_db = np.sum(y_hat - y)/m
    return dj_dw, dj_db

# %%
def gradient_descent(x, y, w, b,lamda, alpha, num_iters, cost_func, grad):
    w = np.zeros(model_polynomial.shape[1])
    for i in range(num_iters):
        y_hat = model(x, w, b)
        dj_dw, dj_db = grad(x, y, y_hat)     
        w -= alpha * dj_dw + (lamda*np.sum(w)/m)
        b -= alpha * dj_db 
        J_history.append(cost_func(y_hat, y, w, lamda))
        p_history.append([w,b])
    return w, b, J_history, p_history

# %%
w_final, b_final, J_hist, p_hist = gradient_descent(x_traintrain, y_traintrain, w_initial, b_initial, lamda, tmp_alpha, 
                                                    iterations, cost_func, grad)

# %%
# %%time
print(J_hist, w_final, b_final)
# Out:
# [3411073644264.8784, 21476101836.737038, 12509059019.16757, 9400304295.920181, 7146146355.567309, 5491886673.16381, 4268385477.469597, 3357105099.0865693, 2673737759.4941163, 2157754179.2387877, 1765403796.8194036, 1464875177.5448668, 1232914186.2465549, 1052432798.9625077, 910810839.374096, 798681123.5294368, 709056973.6382874, 636701967.2895919, 577672778.958005, 528985853.29557353, 488373323.2158644, 454103413.4820867, 424847718.56736535, 399582668.88204134, 377516062.3538846, 358032042.7188019, 340649717.94088537, 324991904.9256927, 310761425.429967, 297723055.7384867, 285689727.4861539, 274511937.8121616, 264069592.22089407, 254265698.6585315, 245021475.76861173, 236272545.49387103, 227965960.15079427, 220057873.931878, 212511713.75631854, 205296738.30361956, 198386899.74808416, 191759942.23276228, 185396686.01509088, 179280457.62025854, 173396635.10146314, 167732284.26300266, 162275866.92939085, 157017006.40041375, 151946298.39002487, 147055158.2124464, 142335696.90899867, 137780620.5241343, 133383147.93123966, 129136943.5488635, 125036062.03109632, 121074902.60427281, 117248171.18911242, 113550848.81854117, 109978165.1569384, 106525576.16215818, 103188745.11982511, 99963526.4298311, 96845951.64539106, 93832217.36153889, 90918674.62738739, 88101819.